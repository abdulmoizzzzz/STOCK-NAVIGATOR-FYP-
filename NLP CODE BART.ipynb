# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary

# Main function
def main():
    # MongoDB connection parameters
    database_name = "Fidelitycouk"
    raw_collection_name = "rawdatafidelity"
    refined_collection_name = "Refined-data3"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 6684f0b9329a6215f8473033
# Summary 2 updated for document with _id: 6684f0ba329a6215f8473035
# Summary 3 updated for document with _id: 6684f0bb329a6215f8473037
# Summary 4 updated for document with _id: 6684f0bc329a6215f8473039
# Summary 5 updated for document with _id: 6684f0bd329a6215f847303b
# Summary 6 updated for document with _id: 6684f0bd329a6215f847303d
# Summary 7 updated for document with _id: 6684f0be329a6215f847303f
# Summary 8 updated for document with _id: 6684f0be329a6215f8473041
# Summary 9 updated for document with _id: 6684f0bf329a6215f8473043
# Summary 10 updated for document with _id: 6684f0c1329a6215f8473045
# Summary 11 updated for document with _id: 6684f0c1329a6215f8473047
# Summary 12 updated for document with _id: 6684f0c2329a6215f8473049
# Summary 13 updated for document with _id: 6684f0c3329a6215f847304b
# Summary 14 updated for document with _id: 6684f0c3329a6215f847304d
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer

# Loading the pre-trained BART model and tokenizer
model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connect to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection

# Function to fetch data from MongoDB
def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data

# Function to generate summaries using BART model
def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generate the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    
    if not summary.endswith('.'):
        summary += '.'

    return summary

# Main function
def main():
    database_name = "SharesMagazineUk"
    raw_collection_name = "rawdataShares"
    refined_collection_name = "Refined-data2"

    # Connect to MongoDB and fetch data from both collections
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

           
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")

# Execute the main function
if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 6684f18901b4783bf2e1d264
# Summary 2 updated for document with _id: 6684f18b01b4783bf2e1d266
# Summary 3 updated for document with _id: 6684f18c01b4783bf2e1d268
# Summary 4 updated for document with _id: 6684f18d01b4783bf2e1d26a
# Summary 5 updated for document with _id: 6684f18d01b4783bf2e1d26c
# Summary 6 updated for document with _id: 6684f18e01b4783bf2e1d26e
# Summary 7 updated for document with _id: 6684f18f01b4783bf2e1d270
# Summary 8 updated for document with _id: 6684f18f01b4783bf2e1d272
# Summary 9 updated for document with _id: 6684f19001b4783bf2e1d274
# Summary 10 updated for document with _id: 6684f19101b4783bf2e1d276
# Summary 11 updated for document with _id: 6684f19101b4783bf2e1d278
# Summary 12 updated for document with _id: 6684f19201b4783bf2e1d27a
# Summary 13 updated for document with _id: 6684f19401b4783bf2e1d27c
# Summary 14 updated for document with _id: 6684f19501b4783bf2e1d27e
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer

# Loading the pre-trained BART model and tokenizer
model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connect to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection

# Function to fetch data from MongoDB
def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data

# Function to generate summaries using BART model
def generate_summary(Description):
    # Preprocess the input description
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generate the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    # Decode the output summary
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary

# Main function
def main():
    # MongoDB connection parameters
    database_name = "MOTLEYFOOLUK"
    raw_collection_name = "rawdatamotley"
    refined_collection_name = "Refined-data1"

    # Connect to MongoDB and fetch data from both collections
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    # Update the documents in Refined-data3 collection with generated summaries
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  # Ensure to use lowercase 'description' here
            summary = generate_summary(Description)

            # Update the document in Refined-data3 collection with the generated summary
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")

# Execute the main function
if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 6684efdf97eda1b6ccb57839
# Summary 2 updated for document with _id: 6684efe097eda1b6ccb5783b
# Summary 3 updated for document with _id: 6684efe197eda1b6ccb5783d
# Summary 4 updated for document with _id: 6684efe297eda1b6ccb5783f
# Summary 5 updated for document with _id: 6684efe397eda1b6ccb57841
# Summary 6 updated for document with _id: 6684efe397eda1b6ccb57843
# Summary 7 updated for document with _id: 6684efe497eda1b6ccb57845
# Summary 8 updated for document with _id: 6684efe497eda1b6ccb57847
# Summary 9 updated for document with _id: 6684efe597eda1b6ccb57849
# Summary 10 updated for document with _id: 6684efe697eda1b6ccb5784b
# Summary 11 updated for document with _id: 6684efe797eda1b6ccb5784d
# Summary 12 updated for document with _id: 6684efe897eda1b6ccb5784f
# Summary 13 updated for document with _id: 6684efe897eda1b6ccb57851
# Summary 14 updated for document with _id: 6684efe997eda1b6ccb57853
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary

# Main function
def main():
    # MongoDB connection parameters
    database_name = "BenzingaProUSA"
    raw_collection_name = "rawdataBenzinga"
    refined_collection_name = "Refined-data4"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 663f897251846a82a771efb4
# Summary 2 updated for document with _id: 663f897351846a82a771efb6
# Summary 3 updated for document with _id: 663f897451846a82a771efb8
# Summary 4 updated for document with _id: 663f897451846a82a771efba
# Summary 5 updated for document with _id: 663f898251846a82a771efbc
# Summary 6 updated for document with _id: 663f898351846a82a771efbe
# Summary 7 updated for document with _id: 663f898351846a82a771efc0
# Summary 8 updated for document with _id: 663f898b51846a82a771efc2
# Summary 9 updated for document with _id: 663f898c51846a82a771efc4
# Summary 10 updated for document with _id: 663f898f51846a82a771efc6
# Summary 11 updated for document with _id: 663f899151846a82a771efc8
# Summary 12 updated for document with _id: 663f899351846a82a771efca
# Summary 13 updated for document with _id: 663f899651846a82a771efcc
# Summary 14 updated for document with _id: 663f899851846a82a771efce
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary

# Main function
def main():
    # MongoDB connection parameters
    database_name = "BusinessInsiderUSA"
    raw_collection_name = "rawdataBusinessInsider"
    refined_collection_name = "Refined-data5"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 66859a815b00f5b7b6ff1170
# Summary 2 updated for document with _id: 66859a825b00f5b7b6ff1172
# Summary 3 updated for document with _id: 66859a845b00f5b7b6ff1174
# Summary 4 updated for document with _id: 66859a855b00f5b7b6ff1176
# Summary 5 updated for document with _id: 66859a855b00f5b7b6ff1178
# Summary 6 updated for document with _id: 66859a865b00f5b7b6ff117a
# Summary 7 updated for document with _id: 66859a885b00f5b7b6ff117c
# Summary 8 updated for document with _id: 66859a895b00f5b7b6ff117e
# Summary 9 updated for document with _id: 66859a895b00f5b7b6ff1180
# Summary 10 updated for document with _id: 66859a8a5b00f5b7b6ff1182
# Summary 11 updated for document with _id: 66859a8b5b00f5b7b6ff1184
# Summary 12 updated for document with _id: 66859a8c5b00f5b7b6ff1186
# Summary 13 updated for document with _id: 66859a8d5b00f5b7b6ff1188
# Summary 14 updated for document with _id: 66859a8e5b00f5b7b6ff118a
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary

# Main function
def main():
    # MongoDB connection parameters
    database_name = "APNewsUSA"
    raw_collection_name = "rawdataAP"
    refined_collection_name = "Refined-data6"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 66859e3846b11aaf8cbd5419
# Summary 2 updated for document with _id: 66859e3946b11aaf8cbd541b
# Summary 3 updated for document with _id: 66859e3a46b11aaf8cbd541d
# Summary 4 updated for document with _id: 66859e3b46b11aaf8cbd541f
# Summary 5 updated for document with _id: 66859e3c46b11aaf8cbd5421
# Summary 6 updated for document with _id: 66859e3d46b11aaf8cbd5423
# Summary 7 updated for document with _id: 66859e3e46b11aaf8cbd5425
# Summary 8 updated for document with _id: 66859e3e46b11aaf8cbd5427
# Summary 9 updated for document with _id: 66859e3f46b11aaf8cbd5429
# Summary 10 updated for document with _id: 66859e4046b11aaf8cbd542b
# Summary 11 updated for document with _id: 66859e4146b11aaf8cbd542d
# Summary 12 updated for document with _id: 66859e4246b11aaf8cbd542f
# Summary 13 updated for document with _id: 66859e4346b11aaf8cbd5431
# Summary 14 updated for document with _id: 66859e4446b11aaf8cbd5433
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary

# Main function
def main():
    # MongoDB connection parameters
    database_name = "MotleyFoolAustralia"
    raw_collection_name = "rawdatamotleyaus"
    refined_collection_name = "Refined-data7"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 663f91e3d366b214ec00f1dd
# Summary 2 updated for document with _id: 663f91e5d366b214ec00f1df
# Summary 3 updated for document with _id: 663f91e5d366b214ec00f1e1
# Summary 4 updated for document with _id: 663f91e6d366b214ec00f1e3
# Summary 5 updated for document with _id: 663f91e7d366b214ec00f1e5
# Summary 6 updated for document with _id: 663f91e8d366b214ec00f1e7
# Summary 7 updated for document with _id: 663f91e9d366b214ec00f1e9
# Summary 8 updated for document with _id: 663f91ead366b214ec00f1eb
# Summary 9 updated for document with _id: 663f91ebd366b214ec00f1ed
# Summary 10 updated for document with _id: 663f91ecd366b214ec00f1ef
# Summary 11 updated for document with _id: 663f91ecd366b214ec00f1f1
# Summary 12 updated for document with _id: 663f91edd366b214ec00f1f3
# Summary 13 updated for document with _id: 663f91eed366b214ec00f1f5
# Summary 14 updated for document with _id: 663f91efd366b214ec00f1f7
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary

# Main function
def main():
    # MongoDB connection parameters
    database_name = "NewscomAustralia"
    raw_collection_name = "rawdatanewscom"
    refined_collection_name = "Refined-data8"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 663f93c21e6c9a1a6034d515
# Summary 2 updated for document with _id: 663f93c21e6c9a1a6034d517
# Summary 3 updated for document with _id: 663f93c31e6c9a1a6034d519
# Summary 4 updated for document with _id: 663f93c41e6c9a1a6034d51b
# Summary 5 updated for document with _id: 663f93c51e6c9a1a6034d51d
# Summary 6 updated for document with _id: 663f93c61e6c9a1a6034d51f
# Summary 7 updated for document with _id: 663f93c71e6c9a1a6034d521
# Summary 8 updated for document with _id: 663f93c81e6c9a1a6034d523
# Summary 9 updated for document with _id: 663f93c81e6c9a1a6034d525
# Summary 10 updated for document with _id: 663f93c91e6c9a1a6034d527
# Summary 11 updated for document with _id: 663f93cb1e6c9a1a6034d529
# Summary 12 updated for document with _id: 663f93cc1e6c9a1a6034d52b
# Summary 13 updated for document with _id: 663f93cd1e6c9a1a6034d52d
# Summary 14 updated for document with _id: 663f93ce1e6c9a1a6034d52f
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary

# Main function
def main():
    # MongoDB connection parameters
    database_name = "RaskMediaAustralia"
    raw_collection_name = "rawdatarask"
    refined_collection_name = "Refined-data9"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 663f92f24fe651fe848d9620
# Summary 2 updated for document with _id: 663f92f34fe651fe848d9622
# Summary 3 updated for document with _id: 663f92f44fe651fe848d9624
# Summary 4 updated for document with _id: 663f92f54fe651fe848d9626
# Summary 5 updated for document with _id: 663f92f64fe651fe848d9628
# Summary 6 updated for document with _id: 663f92f74fe651fe848d962a
# Summary 7 updated for document with _id: 663f92f74fe651fe848d962c
# Summary 8 updated for document with _id: 663f92f84fe651fe848d962e
# Summary 9 updated for document with _id: 663f92f94fe651fe848d9630
# Summary 10 updated for document with _id: 663f92fb4fe651fe848d9632
# Summary 11 updated for document with _id: 663f92fb4fe651fe848d9634
# Summary 12 updated for document with _id: 663f92fc4fe651fe848d9636
# Summary 13 updated for document with _id: 663f92fd4fe651fe848d9638
# Summary 14 updated for document with _id: 663f92fd4fe651fe848d963a
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary

# Main function
def main():
    # MongoDB connection parameters
    database_name = "MotleyFoolCanada"
    raw_collection_name = "rawdatamotleycanada"
    refined_collection_name = "Refined-data10"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 6645f1a613c6361b80621ee5
# Summary 2 updated for document with _id: 6645f1a813c6361b80621ee7
# Summary 3 updated for document with _id: 6645f1a913c6361b80621ee9
# Summary 4 updated for document with _id: 6645f1aa13c6361b80621eeb
# Summary 5 updated for document with _id: 6645f1ab13c6361b80621eed
# Summary 6 updated for document with _id: 6645f1ac13c6361b80621eef
# Summary 7 updated for document with _id: 6645f1ac13c6361b80621ef1
# Summary 8 updated for document with _id: 6645f1ad13c6361b80621ef3
# Summary 9 updated for document with _id: 6645f1ae13c6361b80621ef5
# Summary 10 updated for document with _id: 6645f1af13c6361b80621ef7
# Summary 11 updated for document with _id: 6645f1b013c6361b80621ef9
# Summary 12 updated for document with _id: 6645f1b113c6361b80621efb
# Summary 13 updated for document with _id: 6645f1b213c6361b80621efd
# Summary 14 updated for document with _id: 6645f1b413c6361b80621eff
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary


def main():
    # MongoDB connection parameters
    database_name = "StockHouseCanada"
    raw_collection_name = "rawdatastockhouse"
    refined_collection_name = "Refined-data11"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 663f9574bdb8fd61a5c85cbf
# Summary 2 updated for document with _id: 663f9576bdb8fd61a5c85cc1
# Summary 3 updated for document with _id: 663f9577bdb8fd61a5c85cc3
# Summary 4 updated for document with _id: 663f9579bdb8fd61a5c85cc5
# Summary 5 updated for document with _id: 663f957abdb8fd61a5c85cc7
# Summary 6 updated for document with _id: 663f957bbdb8fd61a5c85cc9
# Summary 7 updated for document with _id: 663f957cbdb8fd61a5c85ccb
# Summary 8 updated for document with _id: 663f957fbdb8fd61a5c85ccd
# Summary 9 updated for document with _id: 663f9582bdb8fd61a5c85ccf
# Summary 10 updated for document with _id: 663f9584bdb8fd61a5c85cd1
# Summary 11 updated for document with _id: 663f9585bdb8fd61a5c85cd3
# Summary 12 updated for document with _id: 663f9587bdb8fd61a5c85cd5
# Summary 13 updated for document with _id: 663f958cbdb8fd61a5c85cd7
# Summary 14 updated for document with _id: 663f958cbdb8fd61a5c85cd9
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary


def main():
    # MongoDB connection parameters
    database_name = "SimplywallGermany"
    raw_collection_name = "rawdatasimply"
    refined_collection_name = "Refined-data12"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 663f7e1645bc062ddc5dfe3a
# Summary 2 updated for document with _id: 663f7e1745bc062ddc5dfe3c
# Summary 3 updated for document with _id: 663f7e1a45bc062ddc5dfe3e
# Summary 4 updated for document with _id: 663f7e1c45bc062ddc5dfe40
# Summary 5 updated for document with _id: 663f7e1f45bc062ddc5dfe42
# Summary 6 updated for document with _id: 663f7e2045bc062ddc5dfe44
# Summary 7 updated for document with _id: 663f7e2245bc062ddc5dfe46
# Summary 8 updated for document with _id: 663f7e2a45bc062ddc5dfe48
# Summary 9 updated for document with _id: 663f7e5d45bc062ddc5dfe4a
# Summary 10 updated for document with _id: 663f7e5e45bc062ddc5dfe4c
# Summary 11 updated for document with _id: 663f7e5f45bc062ddc5dfe4e
# Summary 12 updated for document with _id: 663f7e6045bc062ddc5dfe50
# Summary 13 updated for document with _id: 663f7e6145bc062ddc5dfe52
# Summary 14 updated for document with _id: 663f7e6245bc062ddc5dfe54
# ...

# %%
from pymongo import MongoClient
from transformers import BartForConditionalGeneration, BartTokenizer


model_name = "nickmuchi/fb-bart-large-finetuned-trade-the-event-finance-summarizer"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

# Function to connecting to MongoDB
def connect_to_mongodb(database_name, collection_name):
    client = MongoClient("mongodb+srv://moiz121:test123456@cluster0.lq8grwq.mongodb.net/")  
    db = client[database_name]  
    collection = db[collection_name]  
    return collection


def fetch_data_from_mongodb(collection):
    data = []
    for document in collection.find():
        data.append(document)  
    return data


def generate_summary(Description):
    
    input_text = "summarize: " + Description
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True).input_ids

    # Generating the summary
    output_ids = model.generate(
        input_ids,
        max_length=250, 
        num_beams=4,     
        length_penalty=1.0,  
        early_stopping=True,
        min_length=50     
    )

    
    summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # Ensure the summary ends with a full stop
    if not summary.endswith('.'):
        summary += '.'

    return summary


def main():
    # MongoDB connection parameters
    database_name = "CapitalComGermany&global"
    raw_collection_name = "rawdatacapital"
    refined_collection_name = "Refined-data13"

   
    raw_collection = connect_to_mongodb(database_name, raw_collection_name)
    refined_collection = connect_to_mongodb(database_name, refined_collection_name)

    raw_data = fetch_data_from_mongodb(raw_collection)
    refined_data = fetch_data_from_mongodb(refined_collection)

    
    if raw_data and refined_data:
        for idx, (raw_doc, refined_doc) in enumerate(zip(raw_data, refined_data), 1):
            Description = raw_doc['Description']  
            summary = generate_summary(Description)

            
            refined_collection.update_one({'_id': refined_doc['_id']}, {'$set': {'summary': summary}})
            print(f"Summary {idx} updated for document with _id: {refined_doc['_id']}")
    else:
        print("No data found in one of the collections.")


if __name__ == "__main__":
    main()
# Out:
# Summary 1 updated for document with _id: 663f7b42ab9af3cda1dc9339
# Summary 2 updated for document with _id: 663f7b44ab9af3cda1dc933b
# Summary 3 updated for document with _id: 663f7b44ab9af3cda1dc933d
# Summary 4 updated for document with _id: 663f7b46ab9af3cda1dc933f
# Summary 5 updated for document with _id: 663f7b47ab9af3cda1dc9341
# Summary 6 updated for document with _id: 663f7b47ab9af3cda1dc9343
# Summary 7 updated for document with _id: 663f7b48ab9af3cda1dc9345
# Summary 8 updated for document with _id: 663f7b49ab9af3cda1dc9347
# Summary 9 updated for document with _id: 663f7b4aab9af3cda1dc9349
# Summary 10 updated for document with _id: 663f7b4bab9af3cda1dc934b
# Summary 11 updated for document with _id: 663f7b4bab9af3cda1dc934d
# Summary 12 updated for document with _id: 663f7b4cab9af3cda1dc934f
# Summary 13 updated for document with _id: 663f7b4dab9af3cda1dc9351
# Summary 14 updated for document with _id: 663f7b4eab9af3cda1dc9353
# ...

# %%
# Out:
# INFO:     Started server process [7608]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:61198 - "GET /?page=1&page_size=20 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:61201 - "GET /?page=1&page_size=20 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:61204 - "GET /?page=1&page_size=20 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:61206 - "GET /?page=1&page_size=20 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:61208 - "GET /?page=1&page_size=20 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:61209 - "GET /?page=1&page_size=20 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:61215 - "GET /?page=1&page_size=20 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:61221 - "GET /?page=1&page_size=20 HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [7608]
# ...
